# %%
# from data import BodyPartDataset, load_lung_data, load_brain_data, load_breast_data
import data

import matplotlib.pyplot as plt
import importlib
import os
import torch
import cv2
import numpy as np
importlib.reload(data)
# Out:
# <module 'data' from '/Users/tyler1/cmsc472/cmsc472_medicaldiagnosis/data.py'>

# %%
load_lung_data = data.load_lung_data
load_breast_data = data.load_breast_data
load_brain_data = data.load_brain_data
BodyPartDataset = data.BodyPartDataset

# %%
lung_data = BodyPartDataset('lung', load_lung_data, 'data/lung/')

# %%
breast_data = BodyPartDataset('breast', load_breast_data, 'data/breast/')

# %%
brain_data = BodyPartDataset('brain', load_brain_data, 'data/brain/')

# %%
plt.imshow(brain_data.images[0])
print(brain_data.labels[0])
# Out:
# tensor(1)

# %%
plt.imshow(lung_data.images[0])
print(lung_data.labels[0])
# Out:
# tensor(1)

# %%
plt.imshow(breast_data.images[0])
print(breast_data.labels[0])
# Out:
# tensor(0)
