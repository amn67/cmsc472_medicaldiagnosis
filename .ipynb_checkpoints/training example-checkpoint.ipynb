# %%
import importlib
import pydicom as dicom

import data
import torch
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import matplotlib.pylab as plt
from PIL import Image
import numpy as np
import cv2
importlib.reload(data)
# Out:
# <module 'data' from '/Users/rmisra/Desktop/cmsc472_medicaldiagnosis/data.py'>

# %%
all_data = data.load_datasets()

train_set = all_data['lung']['train']
val_set = all_data['lung']['val']

# %%
batch_size = 32
learning_rate = 0.0005
epochs = 100

# %%
train_dataloader = DataLoader(train_set, batch_size=16, shuffle=True)
val_dataloader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

# %%
class BinaryClassifierCNN(nn.Module):
    def __init__(self):
        super(BinaryClassifierCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        self.fc1 = nn.Linear(64 * 32 * 32, 128)
        self.relu4 = nn.ReLU()
        self.fc2 = nn.Linear(128, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.pool1(x)

        x = self.conv2(x)
        x = self.relu2(x)
        x = self.pool2(x)

        x = self.conv3(x)
        x = self.relu3(x)
        x = self.pool3(x)

        x = x.view(-1, 64 * 32 * 32)
        x = self.fc1(x)
        x = self.relu4(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x

# %%
model = BinaryClassifierCNN()  
optim = torch.optim.SGD(model.parameters(), lr = learning_rate) 
loss_function = nn.BCELoss()

# %%
train_loss_epochs = []
val_loss_epochs = []
train_accs_epochs = []
val_accs_epochs = []


for epoch in range(epochs):

    #Training phase
    model.train()  #Setting the model to train phase
    train_loss = []
    val_loss = []

    train_accs = []
    val_accs = []

    for idx, batch in enumerate(train_dataloader):

        x = batch[0].unsqueeze(1)
        x = x
        y = batch[1]

        optim.zero_grad()

        out = model(x)

        loss = loss_function(out, y.float().unsqueeze(1))
        loss.backward()
        optim.step()


        y_pred = torch.round(out)

        train_acc = torch.sum(torch.square(torch.sub(y, y_pred))).item() / (y.size(dim=0))
        train_acc = (torch.squeeze(y_pred).eq(y)).sum().item() / y.size(dim=0)
        
        train_accs.append(train_acc)
        train_loss.append(loss.item())


    #Validation phase
    model.eval()  #Setting the model to eval mode, hence making it deterministic.
    for idx, batch in enumerate(val_dataloader):
        with torch.no_grad():   #Does not calulate the graidents, as in val phase its not needed. Saves on memory.
            x = batch[0].unsqueeze(1)
            y = batch[1]
            out = model.forward(x)
            loss = loss_function(out, y.float().unsqueeze(1))
            y_pred = torch.round(out)
            val_acc = (torch.squeeze(y_pred).eq(y)).sum().item() / y.size(dim=0)
            
            val_loss.append(loss.item())
            val_accs.append(val_acc)
    train_loss_epochs.append(np.mean(train_loss))
    val_loss_epochs.append(np.mean(val_loss))
    train_accs_epochs.append(np.mean(train_accs))
    val_accs_epochs.append(np.mean(val_accs))
    if epoch%1==0:
        print("Epoch : {}, Train loss: {:.5f} , Train Acc: {:.4f}, Val loss: {:.5f}, Val acc: {:.4f}".format(epoch, np.mean(train_loss), np.mean(train_acc), np.mean(val_loss), np.mean(val_acc)))
# Out:
# Epoch : 0, Train loss: 42.37855 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 1, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 2, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 3, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 4, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 5, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 6, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 7, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 8, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 9, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 10, Train loss: 45.97548 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 11, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 12, Train loss: 42.76164 , Train Acc: 0.8333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 13, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 14, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 15, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 16, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 17, Train loss: 51.09497 , Train Acc: 0.1667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 18, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 19, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 20, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 21, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 22, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 23, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 24, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 25, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 26, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 27, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 28, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 29, Train loss: 42.76164 , Train Acc: 0.8333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 30, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 31, Train loss: 42.76164 , Train Acc: 0.8333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 32, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 33, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 34, Train loss: 51.09497 , Train Acc: 0.1667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 35, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 36, Train loss: 42.76164 , Train Acc: 0.8333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 37, Train loss: 43.89215 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 38, Train loss: 44.84497 , Train Acc: 0.6667, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 39, Train loss: 46.92831 , Train Acc: 0.5000, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 40, Train loss: 49.01164 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500
# Epoch : 41, Train loss: 48.05882 , Train Acc: 0.3333, Val loss: 55.00000, Val acc: 0.4500

# %%
plt.figure(figsize=(15, 10))
plt.plot(range(1, epochs+1), train_loss_epochs, label='train loss')
plt.plot(range(1, epochs+1), val_loss_epochs, label='val loss')
plt.xlabel("Epoch", size=14)
plt.ylabel("Loss", size=14)
plt.title("Loss over epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(range(1, epochs+1), train_accs_epochs, label='train acc')
plt.plot(range(1,epochs+1), val_accs_epochs, label='val acc')
plt.xlabel("Epoch", size=14)
plt.ylabel("Accuracy", size=14)
plt.title("Accuracy over epochs", size=14)
plt.legend()
plt.show()
