# %%
import importlib
import pydicom as dicom

import pickle
import data
import torch
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import matplotlib.pylab as plt
from PIL import Image
import numpy as np
import cv2
importlib.reload(data)
# Out:
# <module 'data' from '/Users/shreyashete/Documents/cs projects/CMSC472/cmsc472_medicaldiagnosis/data.py'>

# %%
all_data = data.load_datasets()

train_set = all_data['brain']['train']
val_set = all_data['brain']['val']

# %%
all_data['brain']['train'][0][0]
# Out:
# tensor([[0.2989, 0.2989, 0.2989,  ..., 0.2989, 0.2989, 0.5978],
#         [0.2989, 0.2989, 0.2989,  ..., 0.2989, 0.5978, 0.5978],
#         [0.2989, 0.2989, 0.2989,  ..., 0.5978, 0.5978, 0.2989],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]])

# %%
batch_size = 32
learning_rate = 0.0005
epochs = 50

# %%
train_dataloader = DataLoader(train_set, batch_size=16, shuffle=True)
val_dataloader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

# %%
class BinaryClassifierCNN(nn.Module):
    def __init__(self):
        super(BinaryClassifierCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.batchnorm1 = nn.BatchNorm2d(num_features=16)
        self.dropout1 = nn.Dropout(0.3)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.batchnorm2 = nn.BatchNorm2d(num_features=32)
        self.dropout2 = nn.Dropout(0.3)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.batchnorm3 = nn.BatchNorm2d(num_features=64)
        self.dropout3 = nn.Dropout(0.3)

        self.fc1 = nn.Linear(64 * 32 * 32, 128)
        self.relu4 = nn.ReLU()
        self.dropout4=nn.Dropout(0.3)
        self.fc2 = nn.Linear(128, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.pool1(x)
        x = self.batchnorm1(x)
        x = self.dropout1(x)

        x = self.conv2(x)
        x = self.relu2(x)
        x = self.pool2(x)
        x = self.batchnorm2(x)
        x = self.dropout2(x)

        x = self.conv3(x)
        x = self.relu3(x)
        x = self.pool3(x)
        x = self.batchnorm3(x)
        x = self.dropout3(x)

        x = x.view(-1, 64 * 32 * 32)
        x = self.fc1(x)
        x = self.relu4(x)
        x = self.dropout4(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x

# %%
model = BinaryClassifierCNN()  
optim = torch.optim.SGD(model.parameters(), lr = learning_rate) 
loss_function = nn.BCELoss()

# %%
train_loss_epochs = []
val_loss_epochs = []
train_accs_epochs = []
val_accs_epochs = []


for epoch in range(epochs):

    #Training phase
    model.train()  #Setting the model to train phase
    train_loss = []
    val_loss = []

    train_accs = []
    val_accs = []

    for idx, batch in enumerate(train_dataloader):

        x = batch[0].unsqueeze(1)
        y = batch[1]

        optim.zero_grad()

        out = model(x)

        loss = loss_function(out, y.float().unsqueeze(1))
        loss.backward()
        optim.step()


        y_pred = torch.round(torch.flatten(out))

        train_acc = torch.sum(torch.square(torch.sub(y, y_pred))).item() / (y.size(dim=0))
        train_acc = (torch.squeeze(y_pred).eq(y)).sum().item() / y.size(dim=0)
        train_accs.append(train_acc)
        train_loss.append(loss.item())


    #Validation phase
    model.eval()  #Setting the model to eval mode, hence making it deterministic.
    for idx, batch in enumerate(val_dataloader):
        with torch.no_grad():   #Does not calulate the graidents, as in val phase its not needed. Saves on memory.
            x = batch[0].unsqueeze(1)
            y = batch[1]
            out = model.forward(x)
            loss = loss_function(out, y.float().unsqueeze(1))
            y_pred = torch.round(out)
            val_acc = (torch.squeeze(y_pred).eq(y)).sum().item() / y.size(dim=0)
            
            val_loss.append(loss.item())
            val_accs.append(val_acc)
    train_loss_epochs.append(np.mean(train_loss))
    val_loss_epochs.append(np.mean(val_loss))
    train_accs_epochs.append(np.mean(train_accs))
    val_accs_epochs.append(np.mean(val_accs))
    if epoch%1==0:
        print("Epoch : {}, Train loss: {:.5f} , Train Acc: {:.4f}, Val loss: {:.5f}, Val acc: {:.4f}".format(epoch, np.mean(train_loss), np.mean(train_acc), np.mean(val_loss), np.mean(val_acc)))
# Out:
# Epoch : 0, Train loss: 0.64422 , Train Acc: 0.7143, Val loss: 0.61861, Val acc: 0.8462
# Epoch : 1, Train loss: 0.49649 , Train Acc: 0.9286, Val loss: 0.54335, Val acc: 0.8846
# Epoch : 2, Train loss: 0.42010 , Train Acc: 1.0000, Val loss: 0.48279, Val acc: 0.8846
# Epoch : 3, Train loss: 0.37180 , Train Acc: 0.7857, Val loss: 0.44051, Val acc: 0.8846
# Epoch : 4, Train loss: 0.33488 , Train Acc: 0.7857, Val loss: 0.40756, Val acc: 0.8846
# Epoch : 5, Train loss: 0.31880 , Train Acc: 0.8571, Val loss: 0.38128, Val acc: 0.8846
# Epoch : 6, Train loss: 0.29979 , Train Acc: 1.0000, Val loss: 0.35927, Val acc: 0.8846
# Epoch : 7, Train loss: 0.27566 , Train Acc: 0.9286, Val loss: 0.33984, Val acc: 0.8846
# Epoch : 8, Train loss: 0.25733 , Train Acc: 0.9286, Val loss: 0.32755, Val acc: 0.8846
# Epoch : 9, Train loss: 0.23742 , Train Acc: 1.0000, Val loss: 0.30356, Val acc: 0.8846
# Epoch : 10, Train loss: 0.24019 , Train Acc: 1.0000, Val loss: 0.28922, Val acc: 0.8846
# Epoch : 11, Train loss: 0.22678 , Train Acc: 1.0000, Val loss: 0.27823, Val acc: 0.9231
# Epoch : 12, Train loss: 0.22909 , Train Acc: 0.9286, Val loss: 0.26813, Val acc: 0.9231
# Epoch : 13, Train loss: 0.22030 , Train Acc: 0.9286, Val loss: 0.26187, Val acc: 0.9231
# Epoch : 14, Train loss: 0.21080 , Train Acc: 0.9286, Val loss: 0.25511, Val acc: 0.9231
# Epoch : 15, Train loss: 0.19314 , Train Acc: 0.9286, Val loss: 0.24894, Val acc: 0.8846
# Epoch : 16, Train loss: 0.19540 , Train Acc: 0.9286, Val loss: 0.24546, Val acc: 0.9231
# Epoch : 17, Train loss: 0.17229 , Train Acc: 1.0000, Val loss: 0.24034, Val acc: 0.9231
# Epoch : 18, Train loss: 0.19698 , Train Acc: 0.8571, Val loss: 0.23735, Val acc: 0.9615
# Epoch : 19, Train loss: 0.16923 , Train Acc: 1.0000, Val loss: 0.23267, Val acc: 0.9615
# Epoch : 20, Train loss: 0.17489 , Train Acc: 0.9286, Val loss: 0.23101, Val acc: 0.9231
# Epoch : 21, Train loss: 0.16404 , Train Acc: 1.0000, Val loss: 0.22600, Val acc: 0.9615
# Epoch : 22, Train loss: 0.15300 , Train Acc: 1.0000, Val loss: 0.22289, Val acc: 0.9615
# Epoch : 23, Train loss: 0.15147 , Train Acc: 0.9286, Val loss: 0.21894, Val acc: 0.9615
# Epoch : 24, Train loss: 0.15894 , Train Acc: 0.7143, Val loss: 0.21755, Val acc: 0.9615
# Epoch : 25, Train loss: 0.16396 , Train Acc: 0.8571, Val loss: 0.21664, Val acc: 0.9615
# Epoch : 26, Train loss: 0.14602 , Train Acc: 1.0000, Val loss: 0.21374, Val acc: 0.9615
# Epoch : 27, Train loss: 0.13782 , Train Acc: 1.0000, Val loss: 0.21259, Val acc: 0.9615
# Epoch : 28, Train loss: 0.13811 , Train Acc: 0.9286, Val loss: 0.20969, Val acc: 0.9615
# Epoch : 29, Train loss: 0.13284 , Train Acc: 1.0000, Val loss: 0.20946, Val acc: 0.9615
# Epoch : 30, Train loss: 0.12934 , Train Acc: 1.0000, Val loss: 0.20712, Val acc: 0.9615
# Epoch : 31, Train loss: 0.13192 , Train Acc: 0.9286, Val loss: 0.20514, Val acc: 0.9615
# Epoch : 32, Train loss: 0.12854 , Train Acc: 1.0000, Val loss: 0.20227, Val acc: 0.9615
# Epoch : 33, Train loss: 0.12591 , Train Acc: 1.0000, Val loss: 0.20043, Val acc: 0.9615
# Epoch : 34, Train loss: 0.11561 , Train Acc: 1.0000, Val loss: 0.19905, Val acc: 0.9615
# Epoch : 35, Train loss: 0.11192 , Train Acc: 1.0000, Val loss: 0.19741, Val acc: 0.9615
# Epoch : 36, Train loss: 0.10600 , Train Acc: 1.0000, Val loss: 0.19603, Val acc: 0.9615
# Epoch : 37, Train loss: 0.11467 , Train Acc: 1.0000, Val loss: 0.19401, Val acc: 0.9615
# Epoch : 38, Train loss: 0.10098 , Train Acc: 1.0000, Val loss: 0.19222, Val acc: 0.9615
# Epoch : 39, Train loss: 0.11731 , Train Acc: 1.0000, Val loss: 0.19141, Val acc: 0.9615
# Epoch : 40, Train loss: 0.10386 , Train Acc: 0.9286, Val loss: 0.19091, Val acc: 0.9615
# Epoch : 41, Train loss: 0.10558 , Train Acc: 1.0000, Val loss: 0.19063, Val acc: 0.9615
# Epoch : 42, Train loss: 0.10109 , Train Acc: 0.9286, Val loss: 0.18980, Val acc: 0.9615
# Epoch : 43, Train loss: 0.10841 , Train Acc: 0.9286, Val loss: 0.18683, Val acc: 0.9615
# Epoch : 44, Train loss: 0.11413 , Train Acc: 1.0000, Val loss: 0.18584, Val acc: 0.9615
# Epoch : 45, Train loss: 0.09031 , Train Acc: 1.0000, Val loss: 0.18443, Val acc: 0.9615
# Epoch : 46, Train loss: 0.09611 , Train Acc: 1.0000, Val loss: 0.18379, Val acc: 0.9615
# Epoch : 47, Train loss: 0.09575 , Train Acc: 1.0000, Val loss: 0.18361, Val acc: 0.9615
# Epoch : 48, Train loss: 0.08971 , Train Acc: 1.0000, Val loss: 0.18252, Val acc: 0.9231
# Epoch : 49, Train loss: 0.09551 , Train Acc: 1.0000, Val loss: 0.18076, Val acc: 0.9615

# %%
with open(f'./trained_models/meta_brain.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
plt.figure(figsize=(15, 10))
plt.plot(range(1, epochs+1), train_loss_epochs, label='train loss')
plt.plot(range(1, epochs+1), val_loss_epochs, label='val loss')
plt.xlabel("Epoch", size=14)
plt.ylabel("Loss", size=14)
plt.title("Loss over epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(range(1, epochs+1), train_accs_epochs, label='train acc')
plt.plot(range(1,epochs+1), val_accs_epochs, label='val acc')
plt.xlabel("Epoch", size=14)
plt.ylabel("Accuracy", size=14)
plt.title("Accuracy over epochs", size=14)
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(), './trained_models/brain_meta_weights.pth')
