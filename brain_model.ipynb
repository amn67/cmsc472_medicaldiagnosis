# %%
import importlib
import pydicom as dicom

import pickle
import data
import torch
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import matplotlib.pylab as plt
from PIL import Image
import numpy as np
import cv2
importlib.reload(data)
# Out:
# <module 'data' from '/Users/tyler1/cmsc472/cmsc472_medicaldiagnosis/data.py'>

# %%
all_data = data.load_datasets()

train_set = all_data['brain']['train']
val_set = all_data['brain']['val']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 all_data = data.load_datasets()
#       3 train_set = all_data['brain']['train']
#       4 val_set = all_data['brain']['val']
#
# File ~/cmsc472/cmsc472_medicaldiagnosis/data.py:167, in load_datasets()
#     162 def load_datasets():
#     163     # Returns a dictionary of datasets, where each dataset is a dictionary of train, val, test
#     166     lung_dataset = BodyPartDataset('lung', load_lung_data, 'data/lung/')
# --> 167     breast_dataset = BodyPartDataset('breast', load_breast_data, 'data/breast/')
#     168     brain_dataset = BodyPartDataset('brain', load_brain_data, 'data/brain/')
#     170     datasets = [lung_dataset, breast_dataset, brain_dataset]
#
# File ~/cmsc472/cmsc472_medicaldiagnosis/data.py:22, in BodyPartDataset.__init__(self, part, load_function, data_path)
#      19 self.load_function = load_function
#      20 self.data_path = data_path
# ---> 22 self.images, self.labels = load_function(data_path)
#      24 # Resize to 256x256
#      25 self.images = self.images.unsqueeze(1)
#
# File ~/cmsc472/cmsc472_medicaldiagnosis/data.py:146, in load_breast_data(data_dir)
#     144 def load_breast_data(data_dir):
#     145     files_list = os.listdir(data_dir)
# --> 146     images = [torch.from_numpy(cv2.imread(data_dir+image_path)) for image_path in files_list if image_path != '.DS_Store']
#     147     X = torch.stack(images)
#     149     labels = [int(image_path[-5]) for image_path in files_list if image_path != '.DS_Store']
#
# File ~/cmsc472/cmsc472_medicaldiagnosis/data.py:146, in <listcomp>(.0)
#     144 def load_breast_data(data_dir):
#     145     files_list = os.listdir(data_dir)
# --> 146     images = [torch.from_numpy(cv2.imread(data_dir+image_path)) for image_path in files_list if image_path != '.DS_Store']
#     147     X = torch.stack(images)
#     149     labels = [int(image_path[-5]) for image_path in files_list if image_path != '.DS_Store']
#
# TypeError: expected np.ndarray (got NoneType)

# %%
all_data['brain']['train'][0][0]
# Out:
# tensor([[0.2989, 0.2989, 0.2989,  ..., 0.2989, 0.2989, 0.5978],
#         [0.2989, 0.2989, 0.2989,  ..., 0.2989, 0.5978, 0.5978],
#         [0.2989, 0.2989, 0.2989,  ..., 0.5978, 0.5978, 0.2989],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]])

# %%
batch_size = 32
learning_rate = 0.0005
epochs = 50

# %%
train_dataloader = DataLoader(train_set, batch_size=16, shuffle=True)
val_dataloader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

# %%
class BinaryClassifierCNN(nn.Module):
    def __init__(self):
        super(BinaryClassifierCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        self.fc1 = nn.Linear(64 * 32 * 32, 128)
        self.relu4 = nn.ReLU()
        self.fc2 = nn.Linear(128, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.pool1(x)

        x = self.conv2(x)
        x = self.relu2(x)
        x = self.pool2(x)

        x = self.conv3(x)
        x = self.relu3(x)
        x = self.pool3(x)

        x = x.view(-1, 64 * 32 * 32)
        x = self.fc1(x)
        x = self.relu4(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x

# %%
model = BinaryClassifierCNN()  
optim = torch.optim.SGD(model.parameters(), lr = learning_rate) 
loss_function = nn.BCELoss()

# %%
train_loss_epochs = []
val_loss_epochs = []
train_accs_epochs = []
val_accs_epochs = []


for epoch in range(epochs):

    #Training phase
    model.train()  #Setting the model to train phase
    train_loss = []
    val_loss = []

    train_accs = []
    val_accs = []

    for idx, batch in enumerate(train_dataloader):

        x = batch[0].unsqueeze(1)
        y = batch[1]

        optim.zero_grad()

        out = model(x)

        loss = loss_function(out, y.float().unsqueeze(1))
        loss.backward()
        optim.step()


        y_pred = torch.round(torch.flatten(out))

        train_acc = torch.sum(torch.square(torch.sub(y, y_pred))).item() / (y.size(dim=0))
        train_acc = (torch.squeeze(y_pred).eq(y)).sum().item() / y.size(dim=0)
        train_accs.append(train_acc)
        train_loss.append(loss.item())


    #Validation phase
    model.eval()  #Setting the model to eval mode, hence making it deterministic.
    for idx, batch in enumerate(val_dataloader):
        with torch.no_grad():   #Does not calulate the graidents, as in val phase its not needed. Saves on memory.
            x = batch[0].unsqueeze(1)
            y = batch[1]
            out = model.forward(x)
            loss = loss_function(out, y.float().unsqueeze(1))
            y_pred = torch.round(out)
            val_acc = (torch.squeeze(y_pred).eq(y)).sum().item() / y.size(dim=0)
            
            val_loss.append(loss.item())
            val_accs.append(val_acc)
    train_loss_epochs.append(np.mean(train_loss))
    val_loss_epochs.append(np.mean(val_loss))
    train_accs_epochs.append(np.mean(train_accs))
    val_accs_epochs.append(np.mean(val_accs))
    if epoch%1==0:
        print("Epoch : {}, Train loss: {:.5f} , Train Acc: {:.4f}, Val loss: {:.5f}, Val acc: {:.4f}".format(epoch, np.mean(train_loss), np.mean(train_acc), np.mean(val_loss), np.mean(val_acc)))
# Out:
# Epoch : 0, Train loss: 0.67309 , Train Acc: 0.9286, Val loss: 0.87401, Val acc: 0.4231
# Epoch : 1, Train loss: 0.44133 , Train Acc: 0.8571, Val loss: 0.41570, Val acc: 0.8846
# Epoch : 2, Train loss: 0.47485 , Train Acc: 0.9286, Val loss: 0.40306, Val acc: 0.8846
# Epoch : 3, Train loss: 0.43586 , Train Acc: 0.9286, Val loss: 0.32532, Val acc: 0.8846
# Epoch : 4, Train loss: 0.29417 , Train Acc: 0.9286, Val loss: 0.47331, Val acc: 0.8077
# Epoch : 5, Train loss: 0.28227 , Train Acc: 1.0000, Val loss: 0.29828, Val acc: 0.8846
# Epoch : 6, Train loss: 0.21931 , Train Acc: 0.9286, Val loss: 0.35163, Val acc: 0.8462
# Epoch : 7, Train loss: 0.18021 , Train Acc: 1.0000, Val loss: 0.28607, Val acc: 0.8846
# Epoch : 8, Train loss: 0.19882 , Train Acc: 1.0000, Val loss: 0.23639, Val acc: 0.9231
# Epoch : 9, Train loss: 0.27297 , Train Acc: 0.9286, Val loss: 0.32168, Val acc: 0.8846
# Epoch : 10, Train loss: 0.16259 , Train Acc: 0.8571, Val loss: 0.56593, Val acc: 0.7692
# Epoch : 11, Train loss: 0.19551 , Train Acc: 1.0000, Val loss: 0.27371, Val acc: 0.8462
# Epoch : 12, Train loss: 0.15637 , Train Acc: 0.9286, Val loss: 0.23533, Val acc: 0.8846
# Epoch : 13, Train loss: 0.11270 , Train Acc: 1.0000, Val loss: 0.19627, Val acc: 0.9615
# Epoch : 14, Train loss: 0.10742 , Train Acc: 1.0000, Val loss: 0.18424, Val acc: 0.8846
# Epoch : 15, Train loss: 0.13354 , Train Acc: 0.9286, Val loss: 0.35899, Val acc: 0.8077
# Epoch : 16, Train loss: 0.09543 , Train Acc: 1.0000, Val loss: 0.24079, Val acc: 0.8846
# Epoch : 17, Train loss: 0.08521 , Train Acc: 0.9286, Val loss: 0.27858, Val acc: 0.8846
# Epoch : 18, Train loss: 0.07622 , Train Acc: 1.0000, Val loss: 0.50605, Val acc: 0.7692
# Epoch : 19, Train loss: 0.07240 , Train Acc: 1.0000, Val loss: 0.31541, Val acc: 0.8462
# Epoch : 20, Train loss: 0.07992 , Train Acc: 1.0000, Val loss: 0.17933, Val acc: 0.9231
# Epoch : 21, Train loss: 0.06595 , Train Acc: 1.0000, Val loss: 0.42681, Val acc: 0.7692
# Epoch : 22, Train loss: 0.06854 , Train Acc: 1.0000, Val loss: 0.20400, Val acc: 0.9231
# Epoch : 23, Train loss: 0.07469 , Train Acc: 1.0000, Val loss: 0.21013, Val acc: 0.9231
# Epoch : 24, Train loss: 0.06463 , Train Acc: 1.0000, Val loss: 0.19348, Val acc: 0.9615
# Epoch : 25, Train loss: 0.05630 , Train Acc: 1.0000, Val loss: 0.17365, Val acc: 0.9231
# Epoch : 26, Train loss: 0.04658 , Train Acc: 1.0000, Val loss: 0.42581, Val acc: 0.7692
# Epoch : 27, Train loss: 0.04784 , Train Acc: 1.0000, Val loss: 0.36112, Val acc: 0.8462
# Epoch : 28, Train loss: 0.04750 , Train Acc: 1.0000, Val loss: 0.20462, Val acc: 0.8846
# Epoch : 29, Train loss: 0.03890 , Train Acc: 1.0000, Val loss: 0.36253, Val acc: 0.8462
# Epoch : 30, Train loss: 0.04120 , Train Acc: 1.0000, Val loss: 0.40533, Val acc: 0.8077
# Epoch : 31, Train loss: 0.05177 , Train Acc: 1.0000, Val loss: 0.29127, Val acc: 0.8846
# Epoch : 32, Train loss: 0.03742 , Train Acc: 1.0000, Val loss: 0.31663, Val acc: 0.8462
# Epoch : 33, Train loss: 0.04112 , Train Acc: 1.0000, Val loss: 0.41276, Val acc: 0.8077
# Epoch : 34, Train loss: 0.03404 , Train Acc: 1.0000, Val loss: 0.21494, Val acc: 0.9231
# Epoch : 35, Train loss: 0.03575 , Train Acc: 1.0000, Val loss: 0.22601, Val acc: 0.9231
# Epoch : 36, Train loss: 0.03455 , Train Acc: 1.0000, Val loss: 0.28776, Val acc: 0.8462
# Epoch : 37, Train loss: 0.03306 , Train Acc: 1.0000, Val loss: 0.21746, Val acc: 0.9231
# Epoch : 38, Train loss: 0.02844 , Train Acc: 1.0000, Val loss: 0.26719, Val acc: 0.8462
# Epoch : 39, Train loss: 0.03003 , Train Acc: 1.0000, Val loss: 0.40303, Val acc: 0.8077
# Epoch : 40, Train loss: 0.03013 , Train Acc: 1.0000, Val loss: 0.19569, Val acc: 0.9231
# Epoch : 41, Train loss: 0.02707 , Train Acc: 1.0000, Val loss: 0.35383, Val acc: 0.8462
# Epoch : 42, Train loss: 0.02704 , Train Acc: 1.0000, Val loss: 0.17090, Val acc: 0.9615
# Epoch : 43, Train loss: 0.02860 , Train Acc: 1.0000, Val loss: 0.21772, Val acc: 0.9231
# Epoch : 44, Train loss: 0.02269 , Train Acc: 1.0000, Val loss: 0.23891, Val acc: 0.8462
# Epoch : 45, Train loss: 0.02190 , Train Acc: 1.0000, Val loss: 0.24179, Val acc: 0.8462
# Epoch : 46, Train loss: 0.02092 , Train Acc: 1.0000, Val loss: 0.32794, Val acc: 0.8462
# Epoch : 47, Train loss: 0.02205 , Train Acc: 1.0000, Val loss: 0.26369, Val acc: 0.8462
# Epoch : 48, Train loss: 0.01942 , Train Acc: 1.0000, Val loss: 0.23670, Val acc: 0.8462
# Epoch : 49, Train loss: 0.01879 , Train Acc: 1.0000, Val loss: 0.24174, Val acc: 0.8462

# %%
with open(f'./trained_models/meta_brain.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
plt.figure(figsize=(15, 10))
plt.plot(range(1, epochs+1), train_loss_epochs, label='train loss')
plt.plot(range(1, epochs+1), val_loss_epochs, label='val loss')
plt.xlabel("Epoch", size=14)
plt.ylabel("Loss", size=14)
plt.title("Loss over epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(range(1, epochs+1), train_accs_epochs, label='train acc')
plt.plot(range(1,epochs+1), val_accs_epochs, label='val acc')
plt.xlabel("Epoch", size=14)
plt.ylabel("Accuracy", size=14)
plt.title("Accuracy over epochs", size=14)
plt.legend()
plt.show()
