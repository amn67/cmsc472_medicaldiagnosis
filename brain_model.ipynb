# %%
import importlib
import pydicom as dicom

import pickle
import data
import models
import torch
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import matplotlib.pylab as plt
from PIL import Image
import numpy as np
import cv2

importlib.reload(data)
importlib.reload(models)
# Out:
# <module 'models' from '/Users/amolmenon/Documents/Spring 2023/CMSC472/cmsc472_medicaldiagnosis/models.py'>

# %%
all_data = data.load_datasets()

train_set = all_data['brain']['train']
val_set = all_data['brain']['val']

# %%
batch_size = 32
learning_rate = 0.0005
epochs = 50

# %%
train_dataloader = DataLoader(train_set, batch_size=16, shuffle=True)
val_dataloader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

# %%
model = models.get_model_class('brain')
optim = torch.optim.SGD(model.parameters(), lr = learning_rate) 
loss_function = nn.BCELoss()

# %%
train_loss_epochs = []
val_loss_epochs = []
train_accs_epochs = []
val_accs_epochs = []


for epoch in range(epochs):

    #Training phase
    model.train()  #Setting the model to train phase
    train_loss = []
    val_loss = []

    train_accs = []
    val_accs = []

    for idx, batch in enumerate(train_dataloader):

        x = batch[0].unsqueeze(1)
        y = batch[1]

        optim.zero_grad()

        out = model(x)

        loss = loss_function(out, y.float().unsqueeze(1))
        loss.backward()
        optim.step()


        y_pred = torch.round(torch.flatten(out))

        train_acc = torch.sum(torch.square(torch.sub(y, y_pred))).item() / (y.size(dim=0))
        train_acc = (torch.squeeze(y_pred).eq(y)).sum().item() / y.size(dim=0)
        train_accs.append(train_acc)
        train_loss.append(loss.item())


    #Validation phase
    model.eval()  #Setting the model to eval mode, hence making it deterministic.
    for idx, batch in enumerate(val_dataloader):
        with torch.no_grad():   #Does not calulate the graidents, as in val phase its not needed. Saves on memory.
            x = batch[0].unsqueeze(1)
            y = batch[1]
            out = model.forward(x)
            loss = loss_function(out, y.float().unsqueeze(1))
            y_pred = torch.round(out)
            val_acc = (torch.squeeze(y_pred).eq(y)).sum().item() / y.size(dim=0)
            
            val_loss.append(loss.item())
            val_accs.append(val_acc)
    train_loss_epochs.append(np.mean(train_loss))
    val_loss_epochs.append(np.mean(val_loss))
    train_accs_epochs.append(np.mean(train_accs))
    val_accs_epochs.append(np.mean(val_accs))
    if epoch%1==0:
        print("Epoch : {}, Train loss: {:.5f} , Train Acc: {:.4f}, Val loss: {:.5f}, Val acc: {:.4f}".format(epoch, np.mean(train_loss), np.mean(train_acc), np.mean(val_loss), np.mean(val_acc)))
# Out:
# Epoch : 0, Train loss: 0.70096 , Train Acc: 0.8571, Val loss: 0.43234, Val acc: 0.8846
# Epoch : 1, Train loss: 0.55147 , Train Acc: 0.9286, Val loss: 0.36483, Val acc: 0.8846
# Epoch : 2, Train loss: 0.34407 , Train Acc: 0.8571, Val loss: 0.31922, Val acc: 0.9231
# Epoch : 3, Train loss: 0.31819 , Train Acc: 0.7143, Val loss: 0.36656, Val acc: 0.8077
# Epoch : 4, Train loss: 0.31363 , Train Acc: 1.0000, Val loss: 0.24640, Val acc: 0.9615
# Epoch : 5, Train loss: 0.21639 , Train Acc: 0.9286, Val loss: 0.49342, Val acc: 0.8077
# Epoch : 6, Train loss: 0.20357 , Train Acc: 1.0000, Val loss: 0.24018, Val acc: 0.9231
# Epoch : 7, Train loss: 0.18190 , Train Acc: 0.8571, Val loss: 0.36175, Val acc: 0.8462
# Epoch : 8, Train loss: 0.15865 , Train Acc: 0.9286, Val loss: 0.26762, Val acc: 0.9231
# Epoch : 9, Train loss: 0.15778 , Train Acc: 0.9286, Val loss: 0.25460, Val acc: 0.9231
# Epoch : 10, Train loss: 0.13936 , Train Acc: 0.9286, Val loss: 0.29746, Val acc: 0.8462
# Epoch : 11, Train loss: 0.12839 , Train Acc: 0.9286, Val loss: 0.36871, Val acc: 0.8462
# Epoch : 12, Train loss: 0.11943 , Train Acc: 0.9286, Val loss: 0.29002, Val acc: 0.8846
# Epoch : 13, Train loss: 0.11230 , Train Acc: 1.0000, Val loss: 0.25295, Val acc: 0.9231
# Epoch : 14, Train loss: 0.10087 , Train Acc: 1.0000, Val loss: 0.20435, Val acc: 0.9231
# Epoch : 15, Train loss: 0.10109 , Train Acc: 1.0000, Val loss: 0.27091, Val acc: 0.8846
# Epoch : 16, Train loss: 0.09608 , Train Acc: 0.9286, Val loss: 0.24540, Val acc: 0.9231
# Epoch : 17, Train loss: 0.08966 , Train Acc: 1.0000, Val loss: 0.37569, Val acc: 0.8077
# Epoch : 18, Train loss: 0.08167 , Train Acc: 1.0000, Val loss: 0.18339, Val acc: 0.9231
# Epoch : 19, Train loss: 0.07737 , Train Acc: 1.0000, Val loss: 0.31549, Val acc: 0.8077
# Epoch : 20, Train loss: 0.07738 , Train Acc: 1.0000, Val loss: 0.36380, Val acc: 0.8077
# Epoch : 21, Train loss: 0.07149 , Train Acc: 1.0000, Val loss: 0.42464, Val acc: 0.7692
# Epoch : 22, Train loss: 0.07809 , Train Acc: 1.0000, Val loss: 0.24982, Val acc: 0.8846
# Epoch : 23, Train loss: 0.06711 , Train Acc: 1.0000, Val loss: 0.15697, Val acc: 0.9615
# Epoch : 24, Train loss: 0.06039 , Train Acc: 1.0000, Val loss: 0.21572, Val acc: 0.9231
# Epoch : 25, Train loss: 0.05997 , Train Acc: 1.0000, Val loss: 0.17608, Val acc: 0.9231
# Epoch : 26, Train loss: 0.05879 , Train Acc: 1.0000, Val loss: 0.20915, Val acc: 0.9231
# Epoch : 27, Train loss: 0.05181 , Train Acc: 1.0000, Val loss: 0.18539, Val acc: 0.9231
# Epoch : 28, Train loss: 0.05132 , Train Acc: 1.0000, Val loss: 0.35401, Val acc: 0.8077
# Epoch : 29, Train loss: 0.04777 , Train Acc: 1.0000, Val loss: 0.21678, Val acc: 0.9231
# Epoch : 30, Train loss: 0.04525 , Train Acc: 1.0000, Val loss: 0.40109, Val acc: 0.8077
# Epoch : 31, Train loss: 0.04380 , Train Acc: 1.0000, Val loss: 0.21354, Val acc: 0.9231
# Epoch : 32, Train loss: 0.04403 , Train Acc: 1.0000, Val loss: 0.32503, Val acc: 0.8462
# Epoch : 33, Train loss: 0.04399 , Train Acc: 1.0000, Val loss: 0.22182, Val acc: 0.8846
# Epoch : 34, Train loss: 0.03788 , Train Acc: 1.0000, Val loss: 0.20607, Val acc: 0.9231
# Epoch : 35, Train loss: 0.03761 , Train Acc: 1.0000, Val loss: 0.25369, Val acc: 0.8462
# Epoch : 36, Train loss: 0.04664 , Train Acc: 1.0000, Val loss: 0.27142, Val acc: 0.8462
# Epoch : 37, Train loss: 0.03478 , Train Acc: 1.0000, Val loss: 0.35208, Val acc: 0.8077
# Epoch : 38, Train loss: 0.03674 , Train Acc: 1.0000, Val loss: 0.26239, Val acc: 0.8462
# Epoch : 39, Train loss: 0.03310 , Train Acc: 1.0000, Val loss: 0.24594, Val acc: 0.8462
# Epoch : 40, Train loss: 0.03316 , Train Acc: 1.0000, Val loss: 0.27123, Val acc: 0.8462
# Epoch : 41, Train loss: 0.03080 , Train Acc: 1.0000, Val loss: 0.29283, Val acc: 0.8462
# Epoch : 42, Train loss: 0.03160 , Train Acc: 1.0000, Val loss: 0.34261, Val acc: 0.8462
# Epoch : 43, Train loss: 0.02828 , Train Acc: 1.0000, Val loss: 0.26816, Val acc: 0.8462
# Epoch : 44, Train loss: 0.03213 , Train Acc: 1.0000, Val loss: 0.29591, Val acc: 0.8462
# Epoch : 45, Train loss: 0.02862 , Train Acc: 1.0000, Val loss: 0.27138, Val acc: 0.8462
# Epoch : 46, Train loss: 0.02875 , Train Acc: 1.0000, Val loss: 0.29440, Val acc: 0.8462
# Epoch : 47, Train loss: 0.02513 , Train Acc: 1.0000, Val loss: 0.16739, Val acc: 0.9615
# Epoch : 48, Train loss: 0.02467 , Train Acc: 1.0000, Val loss: 0.24645, Val acc: 0.8462
# Epoch : 49, Train loss: 0.02326 , Train Acc: 1.0000, Val loss: 0.22057, Val acc: 0.8462

# %%
plt.figure(figsize=(15, 10))
plt.plot(range(1, epochs+1), train_loss_epochs, label='train loss')
plt.plot(range(1, epochs+1), val_loss_epochs, label='val loss')
plt.xlabel("Epoch", size=14)
plt.ylabel("Loss", size=14)
plt.title("Loss over epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(range(1, epochs+1), train_accs_epochs, label='train acc')
plt.plot(range(1,epochs+1), val_accs_epochs, label='val acc')
plt.xlabel("Epoch", size=14)
plt.ylabel("Accuracy", size=14)
plt.title("Accuracy over epochs", size=14)
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(), './trained_models/brain_meta_weights.pth')
with open('./trained_models/brain_model_class.pkl', 'wb') as f:
    pickle.dump(model, f)
