# %%
import matplotlib.pylab as plt
from PIL import Image
import numpy as np
import cv2

# %%
image=Image.open("/content/TCGA_CS_6188_20010812_11.tif")
image_path="/content/TCGA_CS_6188_20010812_11.tif"

image.show()
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=256x256 at 0x7FE41CCD2AC0>

# %%
def get_label(image_path):
  value = np.max(cv2.imread(image_path))
  if value>0:
    return 1
  else:
    return 0
