# %%
import matplotlib.pylab as plt
from PIL import Image
import numpy as np
import cv2

# %%
image=Image.open("brain_data/brain_images/TCGA_HT_8563_19981209_9.tif")
print("hello")
image.show()
# Out:
# hello

# %%
img = cv2.imread("brain_data/brain_images/TCGA_HT_8563_19981209_9.tif")
plt.imshow(img,aspect="auto")
plt.show()

# %%
mask_img=cv2.imread("brain_data/brain_mask/TCGA_HT_8563_19981209_9_mask.tif")
plt.imshow(mask_img,aspect="auto")
plt.show()

mask_path="brain_data/brain_mask/TCGA_HT_8563_19981209_9_mask.tif"

# %%
def get_label(image_path):
  value = np.max(cv2.imread(image_path))
  if value>0:
    return 1
  else:
    return 0


get_label(mask_path)
# Out:
# 1
